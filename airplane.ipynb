# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Airline_date_to_load = "Airlines.csv"

# %%
airplane_df = pd.read_csv("Airlines.csv", encoding="ISO-8859-1")
airplane_df
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 0            1      CO     269         SFO       IAH          3    15     205
# 1            2      US    1558         PHX       CLT          3    15     222
# 2            3      AA    2400         LAX       DFW          3    20     165
# 3            4      AA    2466         SFO       DFW          3    20     195
# 4            5      AS     108         ANC       SEA          3    30     202
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 539378  539379      CO     178         OGG       SNA          5  1439     326
# 539379  539380      FL     398         SEA       ATL          5  1439     305
# 539380  539381      FL     609         SFO       MKE          5  1439     255
# 539381  539382      UA      78         HNL       SFO          5  1439     313
# 539382  539383      US    1442         LAX       PHL          5  1439     301
#
#         Delay
# 0           1
# ...

# %%
airplane_df.count()
# Out:
# id             539383
# Airline        539383
# Flight         539383
# AirportFrom    539383
# AirportTo      539383
# DayOfWeek      539383
# Time           539383
# Length         539383
# Delay          539383
# dtype: int64

# %%
airplane_df.isnull()
# Out:
#            id  Airline  Flight  AirportFrom  AirportTo  DayOfWeek   Time  \
# 0       False    False   False        False      False      False  False
# 1       False    False   False        False      False      False  False
# 2       False    False   False        False      False      False  False
# 3       False    False   False        False      False      False  False
# 4       False    False   False        False      False      False  False
# ...       ...      ...     ...          ...        ...        ...    ...
# 539378  False    False   False        False      False      False  False
# 539379  False    False   False        False      False      False  False
# 539380  False    False   False        False      False      False  False
# 539381  False    False   False        False      False      False  False
# 539382  False    False   False        False      False      False  False
#
#         Length  Delay
# 0        False  False
# 1        False  False
# ...

# %%
airplane_df.isnull().sum()
# Out:
# id             0
# Airline        0
# Flight         0
# AirportFrom    0
# AirportTo      0
# DayOfWeek      0
# Time           0
# Length         0
# Delay          0
# dtype: int64

# %%
airplane_df.dtypes
# Out:
# id              int64
# Airline        object
# Flight          int64
# AirportFrom    object
# AirportTo      object
# DayOfWeek       int64
# Time            int64
# Length          int64
# Delay           int64
# dtype: object

# %%
airplane_type = airplane_df.set_index(["Airline"])["Delay"]
airplane_type
# Out:
# Airline
# CO    1
# US    1
# AA    1
# AA    1
# AS    0
#      ..
# CO    0
# FL    0
# FL    0
# UA    1
# US    1
# Name: Delay, Length: 539383, dtype: int64

# %%
no_delay = airplane_df[(airplane_df["Delay"] > 0)]
no_delay
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 0            1      CO     269         SFO       IAH          3    15     205
# 1            2      US    1558         PHX       CLT          3    15     222
# 2            3      AA    2400         LAX       DFW          3    20     165
# 3            4      AA    2466         SFO       DFW          3    20     195
# 5            6      CO    1094         LAX       IAH          3    30     181
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 539373  539374      B6     480         LAX       BOS          5  1435     320
# 539376  539377      B6     717         JFK       SJU          5  1439     220
# 539377  539378      B6     739         JFK       PSE          5  1439     223
# 539381  539382      UA      78         HNL       SFO          5  1439     313
# 539382  539383      US    1442         LAX       PHL          5  1439     301
#
#         Delay
# 0           1
# ...

# %%
delay_df = airplane_df[(airplane_df["Delay"] <= 0)]
delay_df
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 4            5      AS     108         ANC       SEA          3    30     202
# 6            7      DL    1768         LAX       MSP          3    30     220
# 7            8      DL    2722         PHX       DTW          3    30     228
# 12          13      DL    2055         SLC       ATL          3    50     210
# 13          14      AA    2408         LAX       DFW          3    55     170
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 539374  539375      DL    2354         LAX       ATL          5  1435     255
# 539375  539376      FL      58         LAX       ATL          5  1435     250
# 539378  539379      CO     178         OGG       SNA          5  1439     326
# 539379  539380      FL     398         SEA       ATL          5  1439     305
# 539380  539381      FL     609         SFO       MKE          5  1439     255
#
#         Delay
# 4           0
# ...

# %%
delay_df.count()
# Out:
# id             299119
# Airline        299119
# Flight         299119
# AirportFrom    299119
# AirportTo      299119
# DayOfWeek      299119
# Time           299119
# Length         299119
# Delay          299119
# dtype: int64

# %%
print(f'There are {len(airplane_df.Airline.unique())} different airlines')
# Out:
# There are 18 different airlines

# %%
airplane_df.AirportFrom.unique()
# Out:
# array(['SFO', 'PHX', 'LAX', 'ANC', 'LAS', 'SLC', 'DEN', 'ONT', 'FAI',
#        'BQN', 'PSE', 'HNL', 'BIS', 'IYK', 'EWR', 'BOS', 'MKE', 'GFK',
#        'OMA', 'GSO', 'LMT', 'SEA', 'MCO', 'TPA', 'DLH', 'MSP', 'FAR',
#        'MFE', 'MSY', 'VPS', 'BWI', 'MAF', 'LWS', 'RST', 'ALB', 'DSM',
#        'CHS', 'MSN', 'JAX', 'SAT', 'PNS', 'BHM', 'LIT', 'SAV', 'BNA',
#        'ICT', 'ECP', 'DHN', 'MGM', 'CAE', 'PWM', 'ACV', 'EKO', 'PHL',
#        'ATL', 'PDX', 'RIC', 'BTR', 'HRL', 'MYR', 'TUS', 'SBN', 'CAK',
#        'TVC', 'CLE', 'ORD', 'DAY', 'MFR', 'BTV', 'TLH', 'TYS', 'DFW',
#        'FLL', 'AUS', 'CHA', 'CMH', 'LRD', 'BRO', 'CRP', 'LAN', 'PVD',
#        'FWA', 'JFK', 'LGA', 'OKC', 'PIT', 'PBI', 'ORF', 'DCA', 'AEX',
#        'SYR', 'SHV', 'VLD', 'BDL', 'FAT', 'BZN', 'RDM', 'LFT', 'IPL',
#        'EAU', 'ERI', 'BUF', 'IAH', 'MCI', 'AGS', 'ABI', 'GRR', 'LBB',
#        'CLT', 'LEX', 'MBS', 'MOD', 'AMA', 'SGF', 'AZO', 'ABE', 'SWF',
# ...

# %%
airplane_df.AirportTo.unique()
# Out:
# array(['IAH', 'CLT', 'DFW', 'SEA', 'MSP', 'DTW', 'ORD', 'ATL', 'PDX',
#        'JFK', 'SLC', 'HNL', 'PHX', 'MCO', 'OGG', 'LAX', 'KOA', 'ITO',
#        'SFO', 'MIA', 'IAD', 'SMF', 'PHL', 'LIH', 'DEN', 'LGA', 'MEM',
#        'CVG', 'YUM', 'CWA', 'MKE', 'BQN', 'FAI', 'LAS', 'ANC', 'BOS',
#        'LGB', 'FLL', 'SJU', 'EWR', 'DCA', 'BWI', 'RDU', 'MCI', 'TYS',
#        'SAN', 'ONT', 'OAK', 'MDW', 'BNA', 'DAL', 'CLE', 'JAX', 'JNU',
#        'RNO', 'ELP', 'SAT', 'OTZ', 'MBS', 'BDL', 'STL', 'HOU', 'AUS',
#        'SNA', 'SJC', 'LIT', 'TUS', 'TUL', 'CMH', 'LAN', 'IND', 'AMA',
#        'CRP', 'PIT', 'RKS', 'FWA', 'TPA', 'PBI', 'JAN', 'DSM', 'ADQ',
#        'GRB', 'PVD', 'ABQ', 'SDF', 'RSW', 'MSY', 'BUR', 'BOI', 'TLH',
#        'BHM', 'ACV', 'ORF', 'BET', 'KTN', 'RIC', 'SRQ', 'BTR', 'XNA',
#        'MHT', 'GRR', 'SBN', 'SBA', 'ROA', 'CID', 'GPT', 'MFR', 'SGU',
#        'HPN', 'OMA', 'OTH', 'GSP', 'LMT', 'BUF', 'MSN', 'BFL', 'CAE',
# ...

# %%
airplane_df.Length.unique()
# Out:
# array([205, 222, 165, 195, 202, 181, 220, 228, 216, 200, 201, 212, 210,
#        170, 215, 179, 213, 162, 167, 206, 270, 380, 327, 169, 180,  36,
#         85,  53, 111, 135,  41,  44,  68,  49,  75,  93,  95, 166,  97,
#         96,  58, 158,  62,  64,  70,  69,  83,  87,  50, 120, 233,  72,
#         80,  84, 142,  65,  67, 147, 132,  57, 114, 102, 148,  35, 159,
#        112,  46,  76, 128, 185, 231, 164,  74, 174, 110,  59, 144, 109,
#        118, 134,  47, 100,  66,  71, 183, 119, 190, 160, 140, 219, 208,
#         55,  54, 235, 127, 131, 113, 123, 133,  45, 107,  34,  32,  81,
#        130, 129, 115,  60, 145, 175, 105,  61,  38,  90, 137, 101, 103,
#         48, 125,  82, 225, 260, 245, 150, 280, 240, 315, 143, 168, 156,
#        192,  77, 141, 218, 138, 238, 326, 223, 253,  98, 151,  86,  88,
#        116, 157, 161,  79, 155, 121,  40, 146, 136,  78, 139,  73,  89,
#        171, 342, 404,  94, 108, 152, 172, 117, 184, 249, 188,  63, 237,
# ...

# %%
airplane_df.Flight.unique()
# Out:
# array([ 269, 1558, 2400, ..., 3413, 3184, 3387])

# %%
import pandas as pd
from datetime import date, timedelta

# %%
days = {1:'Monday', 2:'Tuesday', 3:'Wednesday', 4:'Thursday', 5:'Friday', 6:'Saturday', 7:'Sunday'}

# %%
airplane_df['DayOfWeek'] = airplane_df['DayOfWeek'].map(days)
airplane_df
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 0            1      CO     269         SFO       IAH  Wednesday    15     205
# 1            2      US    1558         PHX       CLT  Wednesday    15     222
# 2            3      AA    2400         LAX       DFW  Wednesday    20     165
# 3            4      AA    2466         SFO       DFW  Wednesday    20     195
# 4            5      AS     108         ANC       SEA  Wednesday    30     202
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 539378  539379      CO     178         OGG       SNA     Friday  1439     326
# 539379  539380      FL     398         SEA       ATL     Friday  1439     305
# 539380  539381      FL     609         SFO       MKE     Friday  1439     255
# 539381  539382      UA      78         HNL       SFO     Friday  1439     313
# 539382  539383      US    1442         LAX       PHL     Friday  1439     301
#
#         Delay
# 0           1
# ...

# %%
## Create Features DataFrame
features_df = airplane_df.filter(['Flight','Airline', 'AirportFrom', 'AirportTo','DayOfWeek','Time','Length' ], axis = 1)
features_df
# Out:
#         Flight Airline AirportFrom AirportTo  DayOfWeek  Time  Length
# 0          269      CO         SFO       IAH  Wednesday    15     205
# 1         1558      US         PHX       CLT  Wednesday    15     222
# 2         2400      AA         LAX       DFW  Wednesday    20     165
# 3         2466      AA         SFO       DFW  Wednesday    20     195
# 4          108      AS         ANC       SEA  Wednesday    30     202
# ...        ...     ...         ...       ...        ...   ...     ...
# 539378     178      CO         OGG       SNA     Friday  1439     326
# 539379     398      FL         SEA       ATL     Friday  1439     305
# 539380     609      FL         SFO       MKE     Friday  1439     255
# 539381      78      UA         HNL       SFO     Friday  1439     313
# 539382    1442      US         LAX       PHL     Friday  1439     301
#
# [539383 rows x 7 columns]

# %%
#create target df
target_df = airplane_df.filter(['Flight','Airline','Delay'], axis=1)
target_df
# Out:
#         Flight Airline  Delay
# 0          269      CO      1
# 1         1558      US      1
# 2         2400      AA      1
# 3         2466      AA      1
# 4          108      AS      0
# ...        ...     ...    ...
# 539378     178      CO      0
# 539379     398      FL      0
# 539380     609      FL      0
# 539381      78      UA      1
# 539382    1442      US      1
#
# [539383 rows x 3 columns]

# %%
features_df = features_df.rename(columns={'Airline': 'airline', 'AirportFrom' : 'departing_airport','AirportTo': 'arrival_airport','DayOfWeek' : 'weekday','Time' : 'delay_mins','Length' : 'flight_length'})
features_df
# Out:
#         Flight airline departing_airport arrival_airport    weekday  \
# 0          269      CO               SFO             IAH  Wednesday
# 1         1558      US               PHX             CLT  Wednesday
# 2         2400      AA               LAX             DFW  Wednesday
# 3         2466      AA               SFO             DFW  Wednesday
# 4          108      AS               ANC             SEA  Wednesday
# ...        ...     ...               ...             ...        ...
# 539378     178      CO               OGG             SNA     Friday
# 539379     398      FL               SEA             ATL     Friday
# 539380     609      FL               SFO             MKE     Friday
# 539381      78      UA               HNL             SFO     Friday
# 539382    1442      US               LAX             PHL     Friday
#
#         delay_mins  flight_length
# 0               15            205
# 1               15            222
# 2               20            165
# ...

# %%
airline_delay_df = airplane_df.drop(columns=['Time'])
airline_delay_df
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Length  Delay
# 0            1      CO     269         SFO       IAH  Wednesday     205      1
# 1            2      US    1558         PHX       CLT  Wednesday     222      1
# 2            3      AA    2400         LAX       DFW  Wednesday     165      1
# 3            4      AA    2466         SFO       DFW  Wednesday     195      1
# 4            5      AS     108         ANC       SEA  Wednesday     202      0
# ...        ...     ...     ...         ...       ...        ...     ...    ...
# 539378  539379      CO     178         OGG       SNA     Friday     326      0
# 539379  539380      FL     398         SEA       ATL     Friday     305      0
# 539380  539381      FL     609         SFO       MKE     Friday     255      0
# 539381  539382      UA      78         HNL       SFO     Friday     313      1
# 539382  539383      US    1442         LAX       PHL     Friday     301      1
#
# ...

# %%
airline_delay_df
# Out:
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Length  Delay
# 0            1      CO     269         SFO       IAH  Wednesday     205      1
# 1            2      US    1558         PHX       CLT  Wednesday     222      1
# 2            3      AA    2400         LAX       DFW  Wednesday     165      1
# 3            4      AA    2466         SFO       DFW  Wednesday     195      1
# 4            5      AS     108         ANC       SEA  Wednesday     202      0
# ...        ...     ...     ...         ...       ...        ...     ...    ...
# 539378  539379      CO     178         OGG       SNA     Friday     326      0
# 539379  539380      FL     398         SEA       ATL     Friday     305      0
# 539380  539381      FL     609         SFO       MKE     Friday     255      0
# 539381  539382      UA      78         HNL       SFO     Friday     313      1
# 539382  539383      US    1442         LAX       PHL     Friday     301      1
#
# ...

# %%
airline_delay_df.to_csv('new_airlines', index=False)

# %%
# Add this import for sql database
import sqlite3

# %%
# connecting to 'features.db'
conn = sqlite3.connect('Airlines.db')

# %%
# Adding feature_df database
features_df.to_sql(name ='features', con=conn, if_exists='replace', index=False)
conn.commit
# Out:
# <function Connection.commit>

# %%
# Adding target_df to database
target_df.to_sql(name ='target', con=conn, if_exists='replace', index=False)
conn.commit
# Out:
# <function Connection.commit>

# %%
# connecting to 'target.db'
conn = sqlite3.connect('Airlines.db')
